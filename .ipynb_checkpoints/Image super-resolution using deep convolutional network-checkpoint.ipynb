# %%
import scipy
from PIL import Image
from scipy import ndimage
import scipy.misc
import matplotlib.pyplot as plt
import imageio
import numpy as np
import tensorflow as tf

# %%
def imread(path, is_grayscale=True):
    """
    Read image using its path.
    Default value is gray-scale, and image is read by YCbCr format as the paper said.
    """
    if is_grayscale:
        return scipy.misc.imread(path, flatten=True, mode='YCbCr').astype(np.float)
    else:
        return scipy.misc.imread(path, mode='YCbCr').astype(np.float)

def modcrop(image, scale=3):
    """
    To scale down and up the original image, first thing to do is to have no remainder while scaling operation.

    We need to find modulo of height (and width) and scale factor.
    Then, subtract the modulo from height (and width) of original image size.
    There would be no remainder even after scaling operation.
    """
    if len(image.shape) == 3:
        h, w, _ = image.shape
        h = h - np.mod(h, scale)
        w = w - np.mod(w, scale)
        image = image[0:h, 0:w, :]
    else:
        h, w = image.shape
        h = h - np.mod(h, scale)
        w = w - np.mod(w, scale)
        image = image[0:h, 0:w]
        return image

def preprocess(path, scale=3):
    """
    Preprocess single image file
    (1) Read original image as YCbCr format (and grayscale as default)
    (2) Normalize
    (3) Apply image file with bicubic interpolation
    Args:
    path: file path of desired file
    input_: image applied bicubic interpolation (low-resolution)
    label_: image with original resolution (high-resolution)
    """
    image = imread(path, is_grayscale=True)
    label_ = modcrop(image, scale)

    # Must be normalized
    image = image / 255.
    label_ = label_ / 255.

    input_ = scipy.ndimage.interpolation.zoom(label_, (1./scale), prefilter=False)
    input_ = scipy.ndimage.interpolation.zoom(input_, (scale/1.), prefilter=False)

    return input_, label_

# %%
#Get and show the grount truth as well as the low-res resulting image
blurred_image, groudtruth_image = preprocess('butterfly_GT.bmp')

print('Ground Truth image:')
plt.imshow(groudtruth_image)
plt.show()

print('Blurred image:')
plt.imshow(blurred_image)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   import sys
# Ground Truth image:
# Blurred image:

# %%
#Provided model by TAs.
"""Set the image hyper parameters
"""
c_dim = 1
input_size = 255

"""Define the model weights and biases
"""

# define the placeholders for inputs and outputs
inputs = tf.placeholder(tf.float32, [None, input_size, input_size, c_dim], name='inputs')

## ------ Add your code here: set the weight of three conv layers
# replace '0' with your hyper parameter numbers
# conv1 layer with biases: 64 filters with size 9 x 9
# conv2 layer with biases and relu: 32 filters with size 1 x 1
# conv3 layer with biases and NO relu: 1 filter with size 5 x 5
weights = {
    'w1': tf.Variable(tf.random_normal([9, 9, 1, 64], stddev=1e-3), name='w1'),
    'w2': tf.Variable(tf.random_normal([1, 1, 64, 32], stddev=1e-3), name='w2'),
    'w3': tf.Variable(tf.random_normal([5, 5, 32, 1], stddev=1e-3), name='w3')
    }

biases = {
      'b1': tf.Variable(tf.zeros([64]), name='b1'),
      'b2': tf.Variable(tf.zeros([32]), name='b2'),
      'b3': tf.Variable(tf.zeros([1]), name='b3')
    }

conv1 = tf.nn.relu(tf.nn.conv2d(input=inputs,filter=weights['w1'],strides=[1,1,1,1],padding="VALID")+biases['b1'])
##------ Add your code here: to compute non-linear mapping
# conv2 layer with biases and relu: 32 filters with size 1 x 1

conv2 = tf.nn.relu(tf.nn.conv2d(input=conv1,filter=weights['w2'],strides=[1,1,1,1],padding="VALID")+biases['b2'])
##------ Add your code here: compute the reconstruction of high-resolution image
# conv3 layer with biases and NO relu: 1 filter with size 5 x 5
conv3 = tf.nn.conv2d(input=conv2,filter=weights['w3'],strides=[1,1,1,1],padding="VALID")+biases['b3']


# """Load the pre-trained model file
# """
model_path='model/model.npy'
model = np.load(model_path, encoding = 'latin1').item()

##------ Add your code here: show the weights of model and try to visualisa
# variabiles (w1, w2, w3)



"""Initialize the model variabiles (w1, w2, w3, b1, b2, b3) with the pre-trained model file
"""
# launch a session
sess = tf.Session()

for key in weights.keys():
    sess.run(weights[key].assign(model[key]))

for key in biases.keys():
    sess.run(biases[key].assign(model[key]))

"""Run the model and get the SR image
"""
# transform the input to 4-D tensor
input_ = np.expand_dims(np.expand_dims(blurred_image, axis =0), axis=-1)

# run the session
# here you can also run to get feature map like 'conv1' and 'conv2'
ouput_ = sess.run(conv3, feed_dict={inputs: input_})

# %%
print('Ground Truth image:')
plt.imshow(groudtruth_image)
plt.show()

print('Blurred image:')
plt.imshow(blurred_image)
plt.show()

output_image = ouput_.squeeze()
print('SRCNN output:')
plt.imshow(output_image)
plt.show()
# Out:
# Ground Truth image:
# Blurred image:
# SRCNN output:

# %%
import skimage
from skimage.measure import compare_psnr
skimage.measure.compare_psnr(groudtruth_image, output_image, data_range=None, dynamic_range=None)

# %%
from skimage.measure import compare_psnr
from skimage.measure import compare_ssim

print('PSNR of blurry image: ' + str(compare_psnr(groudtruth_image.astype(np.float32),blurred_image.astype(np.float32))))

gt_cropped = groudtruth_image[6:groudtruth_image.shape[0]-6,6:groudtruth_image.shape[1]-6]
output_image_rescaled=scipy.ndimage.interpolation.zoom(output_image, [groudtruth_image.shape[0]/output_image.shape[0],groudtruth_image.shape[1]/output_image.shape[1]], prefilter=False)
print('PSNR of SRCNN image: ' + str(compare_psnr(gt_cropped.astype(np.float32),output_image)))
# Out:
# PSNR of blurry image: 20.4976301683
# PSNR of SRCNN image: 21.7712483033

# %%
#Running only the first convolution
sess = tf.Session()
for key in weights.keys():
    sess.run(weights[key].assign(model[key]))
for key in biases.keys():
    sess.run(biases[key].assign(model[key]))
input_ = np.expand_dims(np.expand_dims(blurred_image, axis =0), axis=-1)
ouput_ = sess.run(conv1, feed_dict={inputs: input_})

plt.figure(figsize=(15,15))
for i in range(ouput_.shape[3]):
    conv =ouput_[:,:,:,i]
    conv = np.reshape(conv, (247,247))
    plt.subplot(8,8,i+1)
    plt.imshow(conv)
plt.show()

# %%
#Running until the second convolution
sess = tf.Session()
for key in weights.keys():
    sess.run(weights[key].assign(model[key]))
for key in biases.keys():
    sess.run(biases[key].assign(model[key]))
input_ = np.expand_dims(np.expand_dims(blurred_image, axis =0), axis=-1)
ouput_ = sess.run(conv2, feed_dict={inputs: input_})

plt.figure(figsize=(15,15))
for i in range(ouput_.shape[3]):
    conv =ouput_[:,:,:,i]
    conv = np.reshape(conv, (247,247))
    plt.subplot(8,8,i+1)
    plt.imshow(conv)
plt.show()
