# %%
import scipy
from PIL import Image
from scipy import ndimage
import scipy.misc
import matplotlib.pyplot as plt
import imageio
import numpy as np
import tensorflow as tf

# %%
butterfly_image = "butterfly_greyscale.png"
image = np.array(ndimage.imread(butterfly_image, flatten=False))
plt.imshow(image)
plt.show()
print('GT image size: ' + str(image.shape))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
# GT image size: (231, 231)

# %%
#We obtain the test image by executing the model in Test mode
#Some modifications were made to the code as the FLAGS.is_training conditional was not being triggered.
butterfly_image = "butterfly_test.png"
test_image = np.array(ndimage.imread(butterfly_image, flatten=False))
plt.imshow(test_image)
plt.show()
print('Test image size: ' + str(test_image.shape))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
# Test image size: (231, 231)

# %%
import skimage
from skimage.measure import compare_psnr
skimage.measure.compare_psnr(image, test_image, data_range=None, dynamic_range=None)
# Out:
# 20.986987861426208
